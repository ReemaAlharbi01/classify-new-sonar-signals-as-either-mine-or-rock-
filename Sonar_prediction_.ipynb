# %% [markdown]
# Here we will use sonar dataset : The dataset consists of sonar signals that were used to discriminate between two classes of objects: rocks and metal cylinders.
# - The output variable is a string “M” for mine and “R” for rock

# %% [markdown]
# ## First prepare the dataset

# %% [markdown]
# # load the dataset

# %%
from google.colab import drive #first we import the drive and allow acces to the drive content
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# We want to add names for the columns
names= []
for i in range(60):
    if i <59:
        names.append(f"Column{i}")
    else:
        names.append("Class")


print(names)
# Out:
# ['Column0', 'Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6', 'Column7', 'Column8', 'Column9', 'Column10', 'Column11', 'Column12', 'Column13', 'Column14', 'Column15', 'Column16', 'Column17', 'Column18', 'Column19', 'Column20', 'Column21', 'Column22', 'Column23', 'Column24', 'Column25', 'Column26', 'Column27', 'Column28', 'Column29', 'Column30', 'Column31', 'Column32', 'Column33', 'Column34', 'Column35', 'Column36', 'Column37', 'Column38', 'Column39', 'Column40', 'Column41', 'Column42', 'Column43', 'Column44', 'Column45', 'Column46', 'Column47', 'Column48', 'Column49', 'Column50', 'Column51', 'Column52', 'Column53', 'Column54', 'Column55', 'Column56', 'Column57', 'Column58', 'Class']

# %%
# Importing pandas to load and interact with the dataset
import pandas as pd

# %%
# Importing the dataset from the drive content
path = '/content/drive/MyDrive/LLM SDAIA bootcsmp/module 2/sonar.csv' # The path of the dataset
dataset = pd.read_csv(path, names=names) # Go to the path and load the dataset
dataset = pd.DataFrame(dataset) # Convert the dataset into a DataFrame to work with

# %% [markdown]
# # Descover the dataset

# %%
#descover the shape of the dataset
dataset.shape
# Out:
# (208, 60)

# %% [markdown]
# so we have 61 columns and 207 rows

# %%
# see the describe information and check the mean and min
dataset.describe()
# Out:
#           Column0     Column1     Column2     Column3     Column4     Column5  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.038437    0.043832    0.053892    0.075202    0.104570    0.121747
# std      0.032960    0.038428    0.046528    0.055552    0.059105    0.061788
# min      0.000600    0.001500    0.005800    0.006700    0.010200    0.003300
# 25%      0.016450    0.018950    0.024375    0.038050    0.067025    0.080900
# 50%      0.030800    0.034300    0.044050    0.062500    0.092150    0.106950
# 75%      0.047950    0.057950    0.064500    0.100275    0.134125    0.154000
# max      0.233900    0.305900    0.426400    0.401000    0.382300    0.372900
#
#           Column6     Column7     Column8     Column9  ...    Column49  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.134799    0.178003    0.208259    0.236013  ...    0.016069
# ...

# %%
#check if there is any missing value and all the coloms intiger
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 208 entries, 0.02 to 0.026
# Data columns (total 60 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column0   208 non-null    float64
#  1   Column1   208 non-null    float64
#  2   Column2   208 non-null    float64
#  3   Column3   208 non-null    float64
#  4   Column4   208 non-null    float64
#  5   Column5   208 non-null    float64
#  6   Column6   208 non-null    float64
#  7   Column7   208 non-null    float64
#  8   Column8   208 non-null    float64
#  9   Column9   208 non-null    float64
#  10  Column10  208 non-null    float64
#  11  Column11  208 non-null    float64
#  12  Column12  208 non-null    float64
#  13  Column13  208 non-null    float64
#  14  Column14  208 non-null    float64
#  15  Column15  208 non-null    float64
#  16  Column16  208 non-null    float64
#  17  Column17  208 non-null    float64
#  18  Column18  208 non-null    float64
# ...

# %%
print(dataset.isnull().sum().sum())
# Out:
# 0

# %%
dataset.head()
# Out:
#         Column0  Column1  Column2  Column3  Column4  Column5  Column6  \
# 0.0200   0.0371   0.0428   0.0207   0.0954   0.0986   0.1539   0.1601
# 0.0453   0.0523   0.0843   0.0689   0.1183   0.2583   0.2156   0.3481
# 0.0262   0.0582   0.1099   0.1083   0.0974   0.2280   0.2431   0.3771
# 0.0100   0.0171   0.0623   0.0205   0.0205   0.0368   0.1098   0.1276
# 0.0762   0.0666   0.0481   0.0394   0.0590   0.0649   0.1209   0.2467
#
#         Column7  Column8  Column9  ...  Column50  Column51  Column52  \
# 0.0200   0.3109   0.2111   0.1609  ...    0.0027    0.0065    0.0159
# 0.0453   0.3337   0.2872   0.4918  ...    0.0084    0.0089    0.0048
# 0.0262   0.5598   0.6194   0.6333  ...    0.0232    0.0166    0.0095
# 0.0100   0.0598   0.1264   0.0881  ...    0.0121    0.0036    0.0150
# 0.0762   0.3564   0.4459   0.4152  ...    0.0031    0.0054    0.0105
#
#         Column53  Column54  Column55  Column56  Column57  Column58  Class
# ...

# %% [markdown]
# Now that there are no null values to handle

# %%
# split the dataset
X = dataset.iloc[:, :-1].astype(float)
Y = dataset.iloc[:, -1]
# Out:
# 0.0200    R
# 0.0453    R
# 0.0262    R
# 0.0100    R
# 0.0762    R
#          ..
# 0.0187    M
# 0.0323    M
# 0.0522    M
# 0.0303    M
# 0.0260    M
# Name: Class, Length: 208, dtype: object

# %%
# Hard coding for the class
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

# %%
#check the balance of the classification in the dataset
import matplotlib.pyplot as plt

# 0--> “M” for mine
# 1--> “R” for rock

import matplotlib.pyplot as plt

Label_1 = len(encoded_Y[encoded_Y == 1])
Label_0 = len(encoded_Y[encoded_Y == 0])
values = [Label_0, Label_1]
labels = ['mine', 'rock']

plt.bar(labels, values, color=['red', 'green'])
# Naming the x-axis
plt.xlabel('Labels')
# Naming the y-axis
plt.ylabel('Counts')
# Plot title
plt.title('Distribution of Labels')

# Show the plot
plt.show()

# %% [markdown]
# # Model Building

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

def create_baseline():
  model=Sequential()
  model.add(Dense(59, input_dim=59, kernel_initializer='normal', activation='relu' ))
  model.add(Dense(1, kernel_initializer='normal', activation='sigmoid' ))

  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %%
# we need it to evaluate the model using the cross validation method by warping the model
# !pip install scikeras

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from scikeras.wrappers import KerasClassifier

# evaluate model with dataset
estimator = KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=5, verbose=0)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=15)
results = cross_val_score(estimator, X, encoded_Y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# evaluate baseline model with standardized dataset
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=5, verbose=0)))

pipeline = Pipeline(estimators)

# %%
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=15)
results = cross_val_score(pipeline, X, encoded_Y, cv=kfold)
print("Standardized: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /usr/local/lib/python3.10/dist-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# ...
